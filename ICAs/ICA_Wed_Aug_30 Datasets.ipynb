# %% [markdown]
# # Numbers and Datasets

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ____
#
# **Guidelines for ICAs**: **Each student will turn in a notebook**. As you work, be sure to divide the effort evenly among your group members. It is strongly recommended that you read the notebook completely first so that you can intelligently divide the work, discuss the ideas, and put results into your own notebook.
#
# The notebook is due at the end of class today - submit this notebook to D2L. Do not worry if you do not complete an ICA; sometimes, we all get stuck on a "silly" coding issue. Just complete as much as you can and write out all of your ideas for the parts you don't get to (e.g., explain what you would have done if you had more time).
#
# **My name is: Mikayla Norton**
#
# *Members of my group:*
#
# * Max Gregg
# * Pranit Ahuja
# * Lan Jin
#
# **Markdown:** All text cells in Jupyter notebooks are written in markdown, which is a handy language that allows you to easily format your text. To see how I wrote this cell with markdown, just double-click on it. If you are not familiar with markdown, [here is a cheat sheet.](https://www.markdownguide.org/cheat-sheet/) Later, you will need to format equations in markdown, which will be done using [$\LaTeX$](https://notebook.community/TwistedHardware/mltutorial/notebooks/jupyter/2.%20Markdown%20&%20LaTeX).
# ____

# %% [markdown]
# ## Instructions
#
#
#
# This In-Class Assignment (ICA) is due at the end of class today.
#
# ✅ Put your name and all of the names of people you worked with today in the markdown cell at the top of this notebook.
#
# There are two goals of this assignment:
# 1. to be aware of the types of data in a given dataset
# 2. to become familiar with a few, very common datasets
#
# ✅ You will work as a group. 🧑🏾‍💻  You will turn in your own assignment to D2L; however, your answers do not need to be the same as the answers of other members of your group. Work together, but feel free to try things on your own as well.
#
# ✅ Read through the next part of the notebook and follow the instructions. Run all of the code. If there is a problem, work with your group members or contact one of the instructors.

# %% [markdown]
# Many datasets are built into various Python libraries. You should know where you can find good datasets so they are readily available. You might also use these datasets in your projects.
#
# We will explore two sources of data in Python: Seaborn and Scikit-Learn. As you will see, these two sources are quite different!
#
# Let's look at what is built into Seaborn. We will learn *a lot* more about Seaborn later in the course; for today, just run the code and understand what is there.

# %%
# bring Seaborn in

import seaborn as sns

# %%
# this is how you get the names of the Seaborn datasets

sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %% [markdown]
# Read in a few datasets from Seaborn. Pay attention to this syntax and where the data is being stored.

# %%
# let's bring in a few datasets from Seaborn so that we can examine them
# --> feel free to examine others that might be interesting to your group

df_titanic = sns.load_dataset("titanic")
df_tips = sns.load_dataset("tips")
df_iris = sns.load_dataset("iris")
df_penguins = sns.load_dataset("penguins")
df_planets = sns.load_dataset("planets")

# %% [markdown]
# Many of these datasets are classics - you will encounter them many, many times.

# %% [markdown]
# ___
# Getting data from Seaborn is pretty easy. We'll get back to these datasets below.
#
# Next, you are going to bring in datasets from `sklearn`. As you will see, the steps are quite different from Seaborn.

# %%
from sklearn import datasets
dir(datasets)
# Out:
# ['__all__',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__getattr__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '_arff_parser',
#  '_base',
#  '_california_housing',
#  '_covtype',
#  '_kddcup99',
#  '_lfw',
#  '_olivetti_faces',
#  '_openml',
#  '_rcv1',
#  '_samples_generator',
#  '_species_distributions',
#  '_svmlight_format_fast',
#  '_svmlight_format_io',
#  '_twenty_newsgroups',
#  'clear_data_home',
#  'dump_svmlight_file',
#  'fetch_20newsgroups',
#  'fetch_20newsgroups_vectorized',
#  'fetch_california_housing',
#  'fetch_covtype',
#  'fetch_kddcup99',
#  'fetch_lfw_pairs',
#  'fetch_lfw_people',
#  'fetch_olivetti_faces',
#  'fetch_openml',
#  'fetch_rcv1',
#  'fetch_species_distributions',
#  'get_data_home',
#  'load_breast_cancer',
#  'load_diabetes',
#  'load_digits',
#  'load_files',
#  'load_iris',
#  'load_linnerud',
#  'load_sample_image',
#  'load_sample_images',
#  'load_svmlight_file',
# ...

# %% [markdown]
# As you can see, there are many more datasets here. Most of these we will ignore for this class, because they are related to detailed issues in machine learning, but there are some nice datasets here that are not in Seaborn.
#
# Let's see how to load a dataset from `sklearn`. Note that what is imported is a container filled with lots of different types of information. It can look like a real mess! But, we can break out each item from the container.

# %%
datasets.load_digits()
# Out:
# {'data': array([[ 0.,  0.,  5., ...,  0.,  0.,  0.],
#         [ 0.,  0.,  0., ..., 10.,  0.,  0.],
#         [ 0.,  0.,  0., ..., 16.,  9.,  0.],
#         ...,
#         [ 0.,  0.,  1., ...,  6.,  0.,  0.],
#         [ 0.,  0.,  2., ..., 12.,  0.,  0.],
#         [ 0.,  0., 10., ..., 12.,  1.,  0.]]),
#  'target': array([0, 1, 2, ..., 8, 9, 8]),
#  'frame': None,
#  'feature_names': ['pixel_0_0',
#   'pixel_0_1',
#   'pixel_0_2',
#   'pixel_0_3',
#   'pixel_0_4',
#   'pixel_0_5',
#   'pixel_0_6',
#   'pixel_0_7',
#   'pixel_1_0',
#   'pixel_1_1',
#   'pixel_1_2',
#   'pixel_1_3',
#   'pixel_1_4',
#   'pixel_1_5',
#   'pixel_1_6',
#   'pixel_1_7',
#   'pixel_2_0',
#   'pixel_2_1',
#   'pixel_2_2',
#   'pixel_2_3',
#   'pixel_2_4',
#   'pixel_2_5',
#   'pixel_2_6',
#   'pixel_2_7',
#   'pixel_3_0',
#   'pixel_3_1',
#   'pixel_3_2',
#   'pixel_3_3',
#   'pixel_3_4',
#   'pixel_3_5',
#   'pixel_3_6',
#   'pixel_3_7',
#   'pixel_4_0',
#   'pixel_4_1',
#   'pixel_4_2',
#   'pixel_4_3',
# ...

# %% [markdown]
# What do you notice? You get a lot of output! This is because the `sklearn` datasets come with additional information. This can be super useful if you are not familiar with the dataset. But, you need to break things apart before you get started. Here is how you do that:

# %%
# actual data
# --> examine others that might be interesting to your group
digits_data = datasets.load_digits().data
wine_data = datasets.load_wine().data
# description of the data
digits_description = datasets.load_digits().DESCR
wine_description = datasets.load_wine().DESCR
# labels for the data
digits_labels = datasets.load_digits().target_names
wine_features = datasets.load_wine().feature_names

# %%
wine_features
# Out:
# ['alcohol',
#  'malic_acid',
#  'ash',
#  'alcalinity_of_ash',
#  'magnesium',
#  'total_phenols',
#  'flavanoids',
#  'nonflavanoid_phenols',
#  'proanthocyanins',
#  'color_intensity',
#  'hue',
#  'od280/od315_of_diluted_wines',
#  'proline']

# %% [markdown]
# ⏸ Pause for a moment and discuss within your group the differences between Seaborn and sklearn datasets. For example, what Python containers (e.g., list? tuple? dictionary?) do they naturally use? What would you do if you needed to convert from one container to another?
#
# ✅ Add some comments to the code below to show you know what it is doing. Add a markdown cell and describe this form of data.

# %%
import matplotlib.pyplot as plt #imports the plotting package
plt.imshow(digits_data[20].reshape(8,8)) # try different elements in the array, prints the pixels using pyplot
digits_data[20]
# Out:
# array([ 0.,  0.,  3., 13., 11.,  7.,  0.,  0.,  0.,  0., 11., 16., 16.,
#        16.,  2.,  0.,  0.,  4., 16.,  9.,  1., 14.,  2.,  0.,  0.,  4.,
#        16.,  0.,  0., 16.,  2.,  0.,  0.,  0., 16.,  1.,  0., 12.,  8.,
#         0.,  0.,  0., 15.,  9.,  0., 13.,  6.,  0.,  0.,  0.,  9., 14.,
#         9., 14.,  1.,  0.,  0.,  0.,  2., 12., 13.,  4.,  0.,  0.])

# %% [markdown]
# Digits data consists of arrays to display a heatmap style image of an integer in an 8x8 grid with values out of a scalar color scale. Each array alement of digits_data is a different integer that is shown by pyplot's imshow function.

# %% [markdown]
# We just read the Seaborn data into Pandas dataframes.
#
# We can view the dataframe by just putting the dataframe name into a cell and using shift-enter:

# %%
df_tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %% [markdown]
# We can also get quick statistics using `describe`:

# %%
df_planets.describe()
# Out:
#             number  orbital_period        mass     distance         year
# count  1035.000000      992.000000  513.000000   808.000000  1035.000000
# mean      1.785507     2002.917596    2.638161   264.069282  2009.070531
# std       1.240976    26014.728304    3.818617   733.116493     3.972567
# min       1.000000        0.090706    0.003600     1.350000  1989.000000
# 25%       1.000000        5.442540    0.229000    32.560000  2007.000000
# 50%       1.000000       39.979500    1.260000    55.250000  2010.000000
# 75%       2.000000      526.005000    3.040000   178.500000  2012.000000
# max       7.000000   730000.000000   25.000000  8500.000000  2014.000000

# %%
df_planets
# Out:
#                method  number  orbital_period   mass  distance  year
# 0     Radial Velocity       1      269.300000   7.10     77.40  2006
# 1     Radial Velocity       1      874.774000   2.21     56.95  2008
# 2     Radial Velocity       1      763.000000   2.60     19.84  2011
# 3     Radial Velocity       1      326.030000  19.40    110.62  2007
# 4     Radial Velocity       1      516.220000  10.50    119.47  2009
# ...               ...     ...             ...    ...       ...   ...
# 1030          Transit       1        3.941507    NaN    172.00  2006
# 1031          Transit       1        2.615864    NaN    148.00  2007
# 1032          Transit       1        3.191524    NaN    174.00  2007
# 1033          Transit       1        4.125083    NaN    293.00  2008
# 1034          Transit       1        4.187757    NaN    260.00  2008
#
# [1035 rows x 6 columns]

# %% [markdown]
# ✅ Pick 4 Seaborn datasets and answer these questions for all 4:
# * how many columns are there in that dataset?
# * what is in each column? that is: real? ordinal? category? nominal?
# * in the first line from `describe`, you have the count - for each of the three datasets you picked, is the count the same for each column? if not, why not?
# * do you see any NaNs in any of your datasets?
# * when you use `describe`, what does Pandas do with columns for which the mean and std don't make any sense?

# %%
df_titanic.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %% [markdown]
# From the titanic dataset:
# 1. There are 15 columns
# 2. Each column:
# * survived: nominal categories [0,1]
# * pclass: ordinal categories [1,2,3]
# * sex: nominal categories [male, female]
# * sibsp: real
# * parch: real
# * fare: real
# * embarked: port of embarkment, could be ordinal based off which stop came first [S, C, Q]
# * class: spelled out version of pclass, ordinal categories [First, Second, Third]
# * who: nominal categories [man, woman, child]
# * adult_male: nominal categories [True, False]
# * deck: could be ordinal categories [A through G]
# * embark_town: spelled out version of embarked, so could be ordinal based off which stop came first
# * alive: nominal category [no, yes]
# * alone: nominal categories [True, False]
# 3. Describe pulls the following columns: survived, pclass, age, sibsp, parch, fare. All but age have the same count, presumably due to empty values in that column.
# 4. Age has 177 NaN values, Deck has 688 NaN values, Embarked/Embark_town each have 2 NaN values
# 5. Those columns are excluded

# %%
df_tips.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %% [markdown]
# From the tips dataset:
# 1. There are 7 columns
# 2. Each column:
# * total_bill: real
# * tip: real
# * sex: nominal categories
# * smoker: nominal categories
# * day: ordinal categories for day of the week
# * time: ordinal categories for time of day
# * size: real, size of party
# 3. describe pulls the following columns: total_bill, tip, and size and all have the same count likely due to the case by case basis of restaurant receipt handling.
# 4. There are no NaN values.

# %%
df_penguins.describe()
# Out:
#        bill_length_mm  bill_depth_mm  flipper_length_mm  body_mass_g
# count      342.000000     342.000000         342.000000   342.000000
# mean        43.921930      17.151170         200.915205  4201.754386
# std          5.459584       1.974793          14.061714   801.954536
# min         32.100000      13.100000         172.000000  2700.000000
# 25%         39.225000      15.600000         190.000000  3550.000000
# 50%         44.450000      17.300000         197.000000  4050.000000
# 75%         48.500000      18.700000         213.000000  4750.000000
# max         59.600000      21.500000         231.000000  6300.000000

# %% [markdown]
# From the penguins dataset:
# 1. There are 7 columns
# 2. Each column:
# * species: nominal categories
# * island: nominal categories
# * bill_length_mm: real
# * bill_depth_mm: real
# * flipper_length_mm: real
# * body_mass_g: real
# * sex: nominal categories
# 3. describe pulls the following columns: bill_length_mm, bill_depth_mm, flipper_length_mm, and body_mass_g, and they all have equal count, likely due to equal NaN values.
# 4. There are 2 NaN values in bill_length_mm, bill_depth_mm, flipper_length_mm, and body_mass_g; and 11 NaN values for sex. This could be due to uncooperative subjects or infantile subjects that are harder to measure.

# %%
df_planets.isna().sum()
# Out:
# method              0
# number              0
# orbital_period     43
# mass              522
# distance          227
# year                0
# dtype: int64

# %% [markdown]
# From the planets dataset:
# 1. There are 6 columns
# 2. Each column:
# * method: nominal categories
# * number: real
# * orbital_period: real
# * mass: real
# * distance: real
# * year: ordinal categories
# 3. describe pulls the following columns: number, orbital_period, mass, distance, year. The count corresponds with the respective missing values discussed in number 4, but they do not match per variable, except for number and year, both columns with no NaN values.
# 4. There are 43 NaN values in orbital_period, 522 in mass, 227 in distance.

# %% [markdown]
# ✅ Within your group, discuss what _message_ each of these datasets has. That is, just by looking at the data, what can you infer about what it might be able to tell you? Summarize that message for three datasets:
#
# 1. message for penguins is: studying how sex, islandic origins, and species can correlate with features of each penguin in terms of size and mass
# 2. message for titanic is: showcases correlations of surviving rates as related to class, age, familial ties, and other features
# 3. message for planets is: explorations of galaxies across several years and the various features of respective galaxies, as well as how the galaxy was found.

# %% [markdown]
# ✅ Next, visualize your datasets. Choose 4 of your favorite Seaborn datasets and use `pairplot` to explore your data. Go to this [website](https://seaborn.pydata.org/generated/seaborn.pairplot.html) and see what the options are. Try several options.
#
# ✅ Answer these questions after each plot:
# * what do you see along the diagonal?
# **the distribution of each variable by color assigned variable**
# * what do you see in the off-diagonal panels?
# **the association of paired variables by x and y axes with colors for each island**
# * for each dataset, do you see a clearer message appearing? what is that message?

# %%
# here is an example for the penguin dataset
sns.pairplot(df_penguins, hue="island")
# Out:
# /Users/mnorton/.pyenv/versions/3.11.3/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# Biscoe island penguins tends to be larger in mass and have most distinctive features.

# %%
sns.pairplot(df_titanic, hue="alive")
# Out:
# /Users/mnorton/.pyenv/versions/3.11.3/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# For the titanic data, the adult male distribution plot by survivorship indicates more women and children likely survived than adult males, and that lower classes had a lower tendency for survival.

# %%
sns.pairplot(df_planets, hue="method")
# Out:
# /Users/mnorton/.pyenv/versions/3.11.3/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# Radial velocity seems to be the most common discovery method for new galaxies up through roughly 2010, transitioning then to transit, but radial velocity can also have a tendency to detect the galaxies furthest away and of greatest mass.

# %%
sns.pairplot(df_tips, hue="time")
# Out:
# /Users/mnorton/.pyenv/versions/3.11.3/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# Dinner correlates with larger party sizes, larger bills, and larger tips.

# %% [markdown]
# Please fill out the form to help us understand the python experiences among the students and evaluate the need for python boot camps: [Python Survey](https://docs.google.com/forms/d/e/1FAIpQLSeZKd5ELiZ9a2ajuK4sawnXUegUvgAIUVuycMFxn_2ATbATfA/viewform?usp=sf_link)
#
# Note that your name and email are not recorded in this survey, unless you include it in a response.

# %% [markdown]
# _____
#
# 👍🏻
#
# Congrats! You have reached the end.
#
# Don't forget to put your name at the top, and the names of the people you worked with.
#
# Upload the notebook into D2L. If you have any trouble, contact Mahyar through Slack.
